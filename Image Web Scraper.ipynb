# %%
import re
import requests
from bs4 import BeautifulSoup
from os.path  import basename
import wget

# %%
url = input("URL: ")
# Out:
# URL: https://www.google.com/search?q=betta+fish&rlz=1C1CHBF_enUS877US877&sxsrf=ALeKk00RHJHD9buraaRK2wBpRPj8UofVQQ:1602428080042&source=lnms&tbm=isch&sa=X&ved=2ahUKEwiBnPTj5azsAhWJg3IEHXDgDmkQ_AUoAXoECDAQAw&biw=1536&bih=731&dpr=1.25

# %%
r = requests.get(url)

soup = BeautifulSoup(r.content, "lxml")

print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="application/xhtml+xml; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="no-cache" name="Cache-Control"/>
#   <title>
#    betta fish - Google Search
#   </title>
#   <style>
# ...

# %%
img_links = []

for i in soup.find_all("img", class_="t0fcAb"):
    img_links.append(i.get("src"))

a = """#for i in img_a_tags:
link = img_a_tags.find("img")
img_link = link.get("src")
print(ext)
    
#file_name = link.get("alt")+"."+ext
    
#link = "https://"+link.get("src")[2:]
    
#img_links.append([file_name, link])
    
print(img_links)"""

for i in img_links:
    print(i)
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcScAnc-LTtVvrFtDurXgOa7Yi-K8qflO-bsN0Z4AwxbU5X3kprYwI2NA1BDpg&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTJ3pGYU2sScXNoxSaWo8E5GnVTFFH2ac9spUiydOFUdYIbzU5JgH38emwDDQ&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_qFY_jA2xBaSnFg0cMP9kVB9PVHDOEXYeshejToexWl2jysyyQLmfowe_KA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQDd12r_jEp1t3kTwryu4Sgw_ETyWmRZNQ9t2XKTrd9WxU_tA8mc5BpVqZQHw&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQRGUUZ7Tm3xSdyQQsG5FNbNZWdS1botC44YOTkVYk7P2aTO4NbE1UIrdZAuRw&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSX3fUInlmW-00txNEM7ekpdPkU06psliLjXgOuYPHd5lD5boAVQnvynfdweA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSlymprzgcxujhJj3OwRFDJJI-g7OHYCmLr_Uy4siV-m-xgM_P2jkyIux5uGGA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTz2wC19nkVHw1YDbl4kDzT-C3XBqX3xAPssu0U3pY3ThslY78pYo6RsuckbxU&s
# ...

# %%
#download imiage from list of [names: source]
name = input("file name:? ")
directory_name = input("Input folder name: ")
directory_name = directory_name.replace("\\", "/")
for i in range(len(img_links)):
    img_url = img_links[i]
    file_name =  "/"+name+str(i)+".jpg"
    file_path = directory_name+file_name

    try:

        img_file = wget.download(img_url, file_path)
        print("downloaded: ", file_name)
    except:
        print("did not download")
        pass
    
    print("Done", img_links[i], file_name)
# Out:
# file name:? betta_fishes
# Input folder name: C:\Users\raksa\Documents\Coding\Personal Coding Projects\Web_scraper_tool\Scraped_data
# 100% [................................................................................] 3374 / 3374downloaded:  /betta_fishes0.jpg
# Done https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcScAnc-LTtVvrFtDurXgOa7Yi-K8qflO-bsN0Z4AwxbU5X3kprYwI2NA1BDpg&s /betta_fishes0.jpg
# 100% [................................................................................] 2501 / 2501downloaded:  /betta_fishes1.jpg
# Done https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTJ3pGYU2sScXNoxSaWo8E5GnVTFFH2ac9spUiydOFUdYIbzU5JgH38emwDDQ&s /betta_fishes1.jpg
# 100% [................................................................................] 4517 / 4517downloaded:  /betta_fishes2.jpg
# Done https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_qFY_jA2xBaSnFg0cMP9kVB9PVHDOEXYeshejToexWl2jysyyQLmfowe_KA&s /betta_fishes2.jpg
# ...

# %%
help(wget.download)
# Out:
# Help on function download in module wget:
#
# download(url, out=None, bar=<function bar_adaptive at 0x000001D096383EE0>)
#     High level function, which downloads URL into tmp file in current
#     directory and then renames it to filename autodetected from either URL
#     or HTTP headers.
#
#     :param bar: function to track download progress (visualize etc.)
#     :param out: output filename or directory
#     :return:    filename where URL is downloaded to

# %%
text = str(input("   "))
text = text.replace("\\", "/")

print(text)
# Out:
#    C:\Users\raksa\Documents\Coding\Personal Coding Projects\Web_scraper_tool
# C:/Users/raksa/Documents/Coding/Personal Coding Projects/Web_scraper_tool
